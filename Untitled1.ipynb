# %%
import tensorflow as tf

# %%
# Check that GPU is available: cf. https://colab.research.google.com/notebooks/gpu.ipynb
assert(tf.config.list_physical_devices('GPU'))

tf.keras.backend.clear_session()
tf.config.optimizer.set_jit(False) # Start with XLA disabled.

def load_data():
  (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
  x_train = x_train.astype('float32') / 256
  x_test = x_test.astype('float32') / 256

  # Convert class vectors to binary class matrices.
  y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
  y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)
  return ((x_train, y_train), (x_test, y_test))

(x_train, y_train), (x_test, y_test) = load_data()

# %%
def generate_model():
  return tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:]),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(32, (3, 3)),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Conv2D(64, (3, 3), padding='same'),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Conv2D(64, (3, 3)),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Activation('softmax')
  ])

model = generate_model()

# %%
def compile_model(model):
  opt = tf.keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)
  model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
  return model

model = compile_model(model)

def train_model(model, x_train, y_train, x_test, y_test, epochs=25):
  model.fit(x_train, y_train, batch_size=256, epochs=epochs, validation_data=(x_test, y_test), shuffle=True)

def warmup(model, x_train, y_train, x_test, y_test):
  # Warm up the JIT, we do not wish to measure the compilation time.
  initial_weights = model.get_weights()
  train_model(model, x_train, y_train, x_test, y_test, epochs=1)
  model.set_weights(initial_weights)

warmup(model, x_train, y_train, x_test, y_test)
# %time train_model(model, x_train, y_train, x_test, y_test)

scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 196/196 [==============================] - 4s 20ms/step - loss: 2.0322 - accuracy: 0.2538 - val_loss: 1.8046 - val_accuracy: 0.3641
# Epoch 1/25
# 196/196 [==============================] - 3s 18ms/step - loss: 2.1097 - accuracy: 0.2188 - val_loss: 1.8589 - val_accuracy: 0.3372
# Epoch 2/25
# 196/196 [==============================] - 3s 18ms/step - loss: 1.7860 - accuracy: 0.3550 - val_loss: 1.6587 - val_accuracy: 0.4091
# Epoch 3/25
# 196/196 [==============================] - 3s 18ms/step - loss: 1.6544 - accuracy: 0.4002 - val_loss: 1.5464 - val_accuracy: 0.4443
# Epoch 4/25
# 196/196 [==============================] - 3s 18ms/step - loss: 1.5707 - accuracy: 0.4337 - val_loss: 1.4664 - val_accuracy: 0.4735
# Epoch 5/25
# 196/196 [==============================] - 3s 18ms/step - loss: 1.5091 - accuracy: 0.4574 - val_loss: 1.4396 - val_accuracy: 0.4822
# Epoch 6/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.4589 - accuracy: 0.4755 - val_loss: 1.3529 - val_accuracy: 0.5192
# Epoch 7/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.4215 - accuracy: 0.4895 - val_loss: 1.4183 - val_accuracy: 0.4975
# Epoch 8/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.3835 - accuracy: 0.5051 - val_loss: 1.2955 - val_accuracy: 0.5399
# Epoch 9/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.3481 - accuracy: 0.5180 - val_loss: 1.2969 - val_accuracy: 0.5411
# Epoch 10/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.3194 - accuracy: 0.5308 - val_loss: 1.2457 - val_accuracy: 0.5604
# Epoch 11/25
# 196/196 [==============================] - 3s 18ms/step - loss: 1.2917 - accuracy: 0.5396 - val_loss: 1.2388 - val_accuracy: 0.5565
# Epoch 12/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.2679 - accuracy: 0.5511 - val_loss: 1.2023 - val_accuracy: 0.5774
# Epoch 13/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.2446 - accuracy: 0.5579 - val_loss: 1.2178 - val_accuracy: 0.5740
# Epoch 14/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.2197 - accuracy: 0.5694 - val_loss: 1.1685 - val_accuracy: 0.5870
# Epoch 15/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.2012 - accuracy: 0.5758 - val_loss: 1.1209 - val_accuracy: 0.6098
# Epoch 16/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1826 - accuracy: 0.5829 - val_loss: 1.1289 - val_accuracy: 0.6045
# Epoch 17/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1610 - accuracy: 0.5912 - val_loss: 1.1149 - val_accuracy: 0.6083
# Epoch 18/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1380 - accuracy: 0.5994 - val_loss: 1.0676 - val_accuracy: 0.6301
# Epoch 19/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1206 - accuracy: 0.6063 - val_loss: 1.1266 - val_accuracy: 0.6012
# Epoch 20/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1052 - accuracy: 0.6118 - val_loss: 1.0797 - val_accuracy: 0.6199
# Epoch 21/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0844 - accuracy: 0.6217 - val_loss: 1.0830 - val_accuracy: 0.6182
# Epoch 22/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0683 - accuracy: 0.6251 - val_loss: 1.0145 - val_accuracy: 0.6477
# Epoch 23/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0539 - accuracy: 0.6326 - val_loss: 0.9908 - val_accuracy: 0.6541
# Epoch 24/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0368 - accuracy: 0.6385 - val_loss: 1.0175 - val_accuracy: 0.6437
# Epoch 25/25
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0181 - accuracy: 0.6448 - val_loss: 0.9676 - val_accuracy: 0.6676
# Wall time: 1min 29s
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9676 - accuracy: 0.6676
# Test loss: 0.9675944447517395
# Test accuracy: 0.6675999760627747

# %%
# We need to clear the session to enable JIT in the middle of the program.
tf.keras.backend.clear_session()
tf.config.optimizer.set_jit(True) # Enable XLA.
model = compile_model(generate_model())
(x_train, y_train), (x_test, y_test) = load_data()

warmup(model, x_train, y_train, x_test, y_test)
# %time train_model(model, x_train, y_train, x_test, y_test)
# Out:
# 196/196 [==============================] - 4s 19ms/step - loss: 2.0674 - accuracy: 0.2347 - val_loss: 1.8339 - val_accuracy: 0.3546
# Epoch 1/25
# 196/196 [==============================] - 5s 28ms/step - loss: 2.1502 - accuracy: 0.1970 - val_loss: 1.9135 - val_accuracy: 0.3234
# Epoch 2/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.8344 - accuracy: 0.3349 - val_loss: 1.7028 - val_accuracy: 0.3964
# Epoch 3/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6890 - accuracy: 0.3894 - val_loss: 1.6599 - val_accuracy: 0.4084
# Epoch 4/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.6065 - accuracy: 0.4208 - val_loss: 1.5938 - val_accuracy: 0.4323
# Epoch 5/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.5418 - accuracy: 0.4424 - val_loss: 1.4417 - val_accuracy: 0.4841
# Epoch 6/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.4825 - accuracy: 0.4654 - val_loss: 1.4125 - val_accuracy: 0.4977
# Epoch 7/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.4351 - accuracy: 0.4853 - val_loss: 1.4599 - val_accuracy: 0.4847
# Epoch 8/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.4009 - accuracy: 0.4967 - val_loss: 1.3497 - val_accuracy: 0.5121
# Epoch 9/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.3667 - accuracy: 0.5110 - val_loss: 1.3863 - val_accuracy: 0.5091
# Epoch 10/25
# 196/196 [==============================] - 3s 17ms/step - loss: 1.3402 - accuracy: 0.5212 - val_loss: 1.2532 - val_accuracy: 0.5591
# Epoch 11/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.3110 - accuracy: 0.5334 - val_loss: 1.2412 - val_accuracy: 0.5627
# Epoch 12/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.2853 - accuracy: 0.5420 - val_loss: 1.2650 - val_accuracy: 0.5520
# Epoch 13/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.2597 - accuracy: 0.5508 - val_loss: 1.2755 - val_accuracy: 0.5515
# Epoch 14/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.2411 - accuracy: 0.5597 - val_loss: 1.2308 - val_accuracy: 0.5634
# Epoch 15/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.2169 - accuracy: 0.5706 - val_loss: 1.1471 - val_accuracy: 0.5976
# Epoch 16/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1967 - accuracy: 0.5757 - val_loss: 1.1405 - val_accuracy: 0.5998
# Epoch 17/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1792 - accuracy: 0.5845 - val_loss: 1.1732 - val_accuracy: 0.5917
# Epoch 18/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1538 - accuracy: 0.5934 - val_loss: 1.1077 - val_accuracy: 0.6083
# Epoch 19/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1364 - accuracy: 0.5989 - val_loss: 1.0990 - val_accuracy: 0.6154
# Epoch 20/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1152 - accuracy: 0.6087 - val_loss: 1.0753 - val_accuracy: 0.6219
# Epoch 21/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.1018 - accuracy: 0.6128 - val_loss: 1.0788 - val_accuracy: 0.6239
# Epoch 22/25
# 196/196 [==============================] - 3s 17ms/step - loss: 1.0830 - accuracy: 0.6206 - val_loss: 1.0137 - val_accuracy: 0.6454
# Epoch 23/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.0647 - accuracy: 0.6275 - val_loss: 1.0390 - val_accuracy: 0.6369
# Epoch 24/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.0474 - accuracy: 0.6315 - val_loss: 0.9956 - val_accuracy: 0.6582
# Epoch 25/25
# 196/196 [==============================] - 3s 16ms/step - loss: 1.0374 - accuracy: 0.6359 - val_loss: 0.9771 - val_accuracy: 0.6615
# Wall time: 1min 22s
